# %%
print("Hello, Alex. Day 0 is working.")
# Out:
# Hello, Alex. Day 0 is working.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.DataFrame({
    "week": [1, 2, 3, 4],
    "progress": [1, 3, 6, 10]
})

print(df)

df.plot(x="week", y="progress")
plt.show()
# Out:
#    week  progress
# 0     1         1
# 1     2         3
# 2     3         6
# 3     4        10
